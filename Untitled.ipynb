# %%
import sys
sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
img1 = cv2.imread('depth/0034.jpg',1)
img = cv2.cvtColor(img1, cv2.COLOR_RGB2HSV)

kernel= None 
lower_red = np.array([100,50,50])
upper_red = np.array([180,255,255])
mask = cv2.inRange(img, lower_red, upper_red)

foog = cv2.createBackgroundSubtractorMOG2()
fgmask = foog.apply(img1)
ret, fgmask = cv2.threshold(fgmask, 250, 255, cv2.THRESH_BINARY)
# Threshold the HSV image using inRange functon to get only red colors
fgmask = cv2.erode(fgmask,kernel,iterations = 1)
fgmask = cv2.dilate(fgmask,kernel,iterations = 2)


image, contours, hierarchy = cv2.findContours(fgmask,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

# loop over each contour in a given frame
for cnt in contours:

    # make sure the contour area is somewhat hihger than some threshold to make sure its a car and not some noise.
    if cv2.contourArea(cnt) > 400:

        # Draw a bounding box around the car and labet it as car detected
        x,y,w,h = cv2.boundingRect(cnt)
        cv2.rectangle(img1,(x ,y),(x+w,y+h),(0,0,255),2)
        cv2.putText(img1,'detected_image',(x,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0,255,0), 1, cv2.LINE_AA)

fgmask_3 = cv2.cvtColor(fgmask, cv2.COLOR_GRAY2BGR)
stacked = np.hstack((fgmask_3,img1))
cv2.imshow('All three',cv2.resize(stacked,None,fx=0.65,fy=0.65))

cv2.destroyAllWindows()

# %%
# initlize video capture object
canny_on_video = True
path_of_image = 'depth/0029.jpg'

if canny_on_video :
    cap = cv2.VideoCapture('depth/depthvideo.mp4')


lower_red = np.array([160,50,50])
upper_red = np.array([180,255,255])


# you can set custom kernel size if you want
kernel= None

# initilize background subtractor object
foog = cv2.createBackgroundSubtractorMOG2()

while(1):
    if canny_on_video:
        ret, frame = cap.read()
        if not ret:
            break
    else:
        frame = cv2.imread(path_of_image,1)
    
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower_red, upper_red)
    # apply background subtraction
    fgmask = foog.apply(mask)
    
    # get rid of the shadows
    ret, fgmask = cv2.threshold(fgmask, 250, 255, cv2.THRESH_BINARY)
    
    # apply some morphological operations to make sure you have a good mask
    fgmask = cv2.erode(fgmask,kernel,iterations = 1)
    fgmask = cv2.dilate(fgmask,kernel,iterations = 2)
    
    # Detect contours in the frame
    image, contours, heirarchy = cv2.findContours(fgmask,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    
    # loop over each contour in a given frame
    for cnt in contours:
        
        # make sure the contour area is somewhat hihger than some threshold to make sure its a car and not some noise.
        if cv2.contourArea(cnt) > 600:
            
            # Draw a bounding box around the car and labet it as car detected
            x,y,w,h = cv2.boundingRect(cnt)
            cv2.rectangle(frame,(x ,y),(x+w,y+h),(0,0,255),2)
            cv2.putText(frame,'Car Detected',(x,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0,255,0), 1, cv2.LINE_AA)

 
    # Stack all both frames and show the image
    fgmask_3 = cv2.cvtColor(fgmask, cv2.COLOR_GRAY2BGR)
    stacked = np.hstack((fgmask_3,frame))
    cv2.imshow('All three',cv2.resize(stacked,None,fx=0.65,fy=0.65))

    k = cv2.waitKey(100) & 0xff
    if k == ord('q'):
        break
    
if canny_on_video:
    cap.release()


cv2.destroyAllWindows()

# %%
print(np.array(img1))

# %%
print(img1.shape)

# %%
print(img.fromarray(data, 'RGB')  )

# %%
image = Image.open('kolala.jpeg')
image = image.imread('kolala.jpeg')
data = asarray(image)

# %%
image = cv2.imread('depth/0034.jpg')
# Converting the image to hsv
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
kernel = None
# define range of red color in HSV
lower_red = np.array([-9, 245, 215])
upper_red = np.array([ 1, 265, 295])
# Threshold the HSV image using inRange functon to get only red colors
mask = cv2.inRange(hsv, lower_red, upper_red)
fgmask = cv2.erode(mask,kernel,iterations = 1)
fgmask = cv2.dilate(mask,kernel,iterations = 1)



plt.figure(figsize=[20,20])
plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(122);plt.imshow(fgmask, cmap='gray');plt.title("Modified Image")

# %%
lower_red = np.array([0,120,70])
upper_red = np.array([10,255,255])

foog = cv2.createBackgroundSubtractorMOG2()
# initlize video capture object
canny_on_video = False
path_of_image = 'depth/0034.jpg'





# you can set custom kernel size if you want


# initilize background subtractor object



frame = cv2.imread(path_of_image,1)

hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
mask = cv2.inRange(hsv, lower_red, upper_red)
# apply background subtraction
fgmask = foog.apply(mask)

# get rid of the shadows
ret, fgmask = cv2.threshold(fgmask, 250, 255, cv2.THRESH_BINARY)

# apply some morphological operations to make sure you have a good mask
fgmask = cv2.erode(fgmask,kernel,iterations = 3)
fgmask = cv2.dilate(fgmask,kernel,iterations = 2)

# Detect contours in the frame
image, contours, heirarchy = cv2.findContours(fgmask,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

# loop over each contour in a given frame
for cnt in contours:

    # make sure the contour area is somewhat hihger than some threshold to make sure its a car and not some noise.
    if cv2.contourArea(cnt) > 100:

        # Draw a bounding box around the car and labet it as car detected
        x,y,w,h = cv2.boundingRect(cnt)
        cv2.rectangle(frame,(x ,y),(x+w,y+h),(0,0,255),2)
        cv2.putText(frame,'Car Detected',(x,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0,255,0), 1, cv2.LINE_AA)


# Stack all both frames and show the image
#fgmask_3 = cv2.cvtColor(fgmask, cv2.COLOR_GRAY2RGB)
#stacked = np.hstack((fgmask_3,frame))


plt.figure(figsize=[20,20])
#plt.subplot(311);plt.imshow(fgmask_3[:,:,::-1]);plt.title("Original Image")
plt.subplot(312);plt.imshow(frame[:,:,::-1]);plt.title("Modified Image")
plt.subplot(313);plt.imshow(mask, cmap='gray');plt.title("Modified Image")

# %%
cap = cv2.VideoCapture('depth/depthvideo.mp4')

# you can set custom kernel size if you want
kernel= None

# initilize background subtractor object
foog = cv2.createBackgroundSubtractorMOG2()

while(1):
    ret, frame = cap.read()
    if not ret:
        break
        
    # apply background subtraction
    fgmask = foog.apply(frame)
    
    # get rid of the shadows
    ret, fgmask =cv2.threshold(fgmask,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    
    # apply some morphological operations to make sure you have a good mask
    fgmask = cv2.erode(fgmask,kernel,iterations = 1)
    fgmask = cv2.dilate(fgmask,kernel,iterations = 2)
    
    # Detect contours in the frame
    image, contours, hierarchy = cv2.findContours(fgmask,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    
    # loop over each contour in a given frame
    for cnt in contours:
        
        # make sure the contour area is somewhat hihger than some threshold to make sure its a car and not some noise.
        if cv2.contourArea(cnt) > 2000:
            
            # Draw a bounding box around the car and labet it as car detected
            x,y,w,h = cv2.boundingRect(cnt)
            cv2.rectangle(frame,(x ,y),(x+w,y+h),(0,0,255),2)
            cv2.putText(frame,'Object Detected',(x,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0,255,0), 1, cv2.LINE_AA)

 
    # Stack all both frames and show the image
    fgmask_3 = cv2.cvtColor(fgmask, cv2.COLOR_GRAY2BGR)
    stacked = np.hstack((fgmask_3,frame))
    cv2.imshow('All three',cv2.resize(stacked,None,fx=0.65,fy=0.65))

    k = cv2.waitKey(200) & 0xff
    if k == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

image_hsv = None   # global ;(
pixel = (20,60,80) # some stupid default

# mouse callback function
def pick_color(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        pixel = image_hsv[y,x]

        #you might want to adjust the ranges(+-10, etc):
        upper =  np.array([pixel[0] + 10, pixel[1] + 10, pixel[2] + 40])
        lower =  np.array([pixel[0] - 10, pixel[1] - 10, pixel[2] - 40])
        print(pixel, lower, upper)

        image_mask = cv2.inRange(image_hsv,lower,upper)
        cv2.imshow("mask",image_mask)

def main():
    import sys
    global image_hsv, pixel # so we can use it in mouse callback

    image_src = cv2.imread('123.jpg')  # pick.py my.png
    if image_src is None:
        print ("the image read is None............")
        return
    cv2.imshow("bgr",image_src)

    ## NEW ##
    cv2.namedWindow('hsv')
    cv2.setMouseCallback('hsv', pick_color)

    # now click into the hsv img , and look at values:
    image_hsv = cv2.cvtColor(image_src,cv2.COLOR_BGR2HSV)
    cv2.imshow("hsv",image_hsv)

    cv2.waitKey(0)
    cv2.destroyAllWindows()

if __name__=='__main__':
    main()
# Out:
# [ 90  68 255] [ 80  58 215] [100  78 295]
